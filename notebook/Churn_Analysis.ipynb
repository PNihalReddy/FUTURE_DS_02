# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("../data/Telco_Dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("../data/Telco_Dataset.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df = pd.read_csv("../data/Telco_Dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("../data/Telco_Dataset.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df = pd.read_csv("../data/Telco_Dataset.csv", encoding='latin1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv("../data/Telco_Dataset.csv", encoding='latin1')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Nihal Reddy

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.aws',
#  '.azure',
#  '.bash_history',
#  '.cagent',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.continuum',
#  '.copilot',
#  '.docker',
#  '.eclipse',
#  '.ghcp-appmod',
#  '.ghcp-appmod-java',
#  '.git',
#  '.gitconfig',
#  '.gk',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.kube',
#  '.lemminx',
#  '.lesshst',
#  '.m2',
#  '.matplotlib',
#  '.node_repl_history',
#  '.p2',
#  '.packettracer',
#  '.streamlit',
#  '.viminfo',
#  '.VirtualBox',
#  '.vscode',
#  '.vscode-shared',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'battery-report.html',
#  'Business-Sales-Analytics',
#  'Churn-Analytics',
#  'Churn_Analysis.ipynb',
#  'Cisco Packet Tracer 9.0.0',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'eclipse',
#  'eclipse-workspace',
#  'Favorites',
#  'FEDF-GIT-A4',
#  'FEDF1',
#  'fedf2',
#  'fedfgit',
#  'file.txt',
#  'Links',
#  'Local Settings',
# ...

# %%
os.listdir("data")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 os.listdir("data")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data'

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Nihal Reddy

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.aws',
#  '.azure',
#  '.bash_history',
#  '.cagent',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.continuum',
#  '.copilot',
#  '.docker',
#  '.eclipse',
#  '.ghcp-appmod',
#  '.ghcp-appmod-java',
#  '.git',
#  '.gitconfig',
#  '.gk',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.kube',
#  '.lemminx',
#  '.lesshst',
#  '.m2',
#  '.matplotlib',
#  '.node_repl_history',
#  '.p2',
#  '.packettracer',
#  '.streamlit',
#  '.viminfo',
#  '.VirtualBox',
#  '.vscode',
#  '.vscode-shared',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'battery-report.html',
#  'Business-Sales-Analytics',
#  'Churn-Analytics',
#  'Churn_Analysis.ipynb',
#  'Cisco Packet Tracer 9.0.0',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'eclipse',
#  'eclipse-workspace',
#  'Favorites',
#  'FEDF-GIT-A4',
#  'FEDF1',
#  'fedf2',
#  'fedfgit',
#  'file.txt',
#  'Links',
#  'Local Settings',
# ...

# %%
os.listdir("..")
# Out:
# ['All Users',
#  'Default',
#  'Default User',
#  'desktop.ini',
#  'Nihal Reddy',
#  'Public']

# %%
df = pd.read_csv("Churn-Analytics/data/Telco_Dataset.csv")

# %%
import os

os.listdir("Churn-Analytics")
# Out:
# ['.ipynb_checkpoints',
#  'cleaned_data',
#  'dashboard',
#  'data',
#  'notebook',
#  'report',
#  'screenshots']

# %%
os.listdir("Churn-Analytics/data")
# Out:
# ['Telco_Dataset.csv']

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.columns.tolist()
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
round(df['Churn'].value_counts(normalize=True)*100,2)
# Out:
# Churn
# No     73.46
# Yes    26.54
# Name: proportion, dtype: float64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df['TotalCharges'].head(10)
# Out:
# 0      29.85
# 1     1889.5
# 2     108.15
# 3    1840.75
# 4     151.65
# 5      820.5
# 6     1949.4
# 7      301.9
# 8    3046.05
# 9    3487.95
# Name: TotalCharges, dtype: object

# %%
df['TotalCharges'].dtype
# Out:
# dtype('O')

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df['TotalCharges'].isnull().sum()
# Out:
# np.int64(11)

# %%
df['TotalCharges'].fillna(df['TotalCharges'].median(), inplace=True)
# Out:
# C:\Users\Nihal Reddy\AppData\Local\Temp\ipykernel_13644\2840544469.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TotalCharges'].fillna(df['TotalCharges'].median(), inplace=True)

# %%
df['TotalCharges'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Tenure Group
df['Tenure_Group'] = pd.cut(
    df['tenure'],
    bins=[0,12,24,48,72],
    labels=[
        '0-12 Months',
        '13-24 Months',
        '25-48 Months',
        '49-72 Months'
    ]
)

# Monthly Charge Group
df['MonthlyCharge_Group'] = pd.cut(
    df['MonthlyCharges'],
    bins=[0,35,70,120],
    labels=['Low','Medium','High']
)

# Churn Flag
df['Churn_Flag'] = df['Churn'].map({
    'No':0,
    'Yes':1
})

# %%
df.groupby('Contract')['Churn_Flag'].mean()*100
# Out:
# Contract
# Month-to-month    42.709677
# One year          11.269518
# Two year           2.831858
# Name: Churn_Flag, dtype: float64

# %%
df.groupby('InternetService')['Churn_Flag'].mean()*100
# Out:
# InternetService
# DSL            18.959108
# Fiber optic    41.892765
# No              7.404980
# Name: Churn_Flag, dtype: float64

# %%
df.groupby('PaymentMethod')['Churn_Flag'].mean()*100
# Out:
# PaymentMethod
# Bank transfer (automatic)    16.709845
# Credit card (automatic)      15.243101
# Electronic check             45.285412
# Mailed check                 19.106700
# Name: Churn_Flag, dtype: float64

# %%
df.groupby('Tenure_Group', observed=True)['Churn_Flag'].mean()*100
# Out:
# Tenure_Group
# 0-12 Months     47.678161
# 13-24 Months    28.710938
# 25-48 Months    20.388959
# 49-72 Months     9.513176
# Name: Churn_Flag, dtype: float64

# %%
df.groupby('SeniorCitizen')['Churn_Flag'].mean()*100
# Out:
# SeniorCitizen
# 0    23.606168
# 1    41.681261
# Name: Churn_Flag, dtype: float64

# %%
df.groupby('gender')['Churn_Flag'].mean()*100
# Out:
# gender
# Female    26.920872
# Male      26.160338
# Name: Churn_Flag, dtype: float64

# %%
df.groupby('Partner')['Churn_Flag'].mean()*100
# Out:
# Partner
# No     32.957979
# Yes    19.664903
# Name: Churn_Flag, dtype: float64

# %%
df.groupby('Dependents')['Churn_Flag'].mean()*100
# Out:
# Dependents
# No     31.279140
# Yes    15.450237
# Name: Churn_Flag, dtype: float64

# %%
df.groupby('Churn')['MonthlyCharges'].mean()
# Out:
# Churn
# No     61.265124
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby('Churn')['tenure'].mean()
# Out:
# Churn
# No     37.569965
# Yes    17.979133
# Name: tenure, dtype: float64

# %%
df.groupby('Churn')['TotalCharges'].mean()
# Out:
# Churn
# No     2552.882494
# Yes    1531.796094
# Name: TotalCharges, dtype: float64

# %%
df.to_csv(
    "Churn-Analytics/cleaned_data/telco_churn_cleaned.csv",
    index=False
)

# %%
df.to_csv(
    "Churn-Analytics/cleaned_data/telco_churn_cleaned.csv",
    index=False
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customerID           7043 non-null   object
#  1   gender               7043 non-null   object
#  2   SeniorCitizen        7043 non-null   int64
#  3   Partner              7043 non-null   object
#  4   Dependents           7043 non-null   object
#  5   tenure               7043 non-null   int64
#  6   PhoneService         7043 non-null   object
#  7   MultipleLines        7043 non-null   object
#  8   InternetService      7043 non-null   object
#  9   OnlineSecurity       7043 non-null   object
#  10  OnlineBackup         7043 non-null   object
#  11  DeviceProtection     7043 non-null   object
#  12  TechSupport          7043 non-null   object
#  13  StreamingTV          7043 non-null   object
#  14  StreamingMovies      7043 non-null   object
# ...

# %%
df['Tenure_Group'] = pd.cut(
    df['tenure'],
    bins=[-1,12,24,48,72],
    labels=[
        '0-12 Months',
        '13-24 Months',
        '25-48 Months',
        '49-72 Months'
    ]
)

# %%
df['Tenure_Group'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.to_csv(
    "Churn-Analytics/cleaned_data/telco_churn_cleaned.csv",
    index=False
)
